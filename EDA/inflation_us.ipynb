# %%
import pandas as pd


df = pd.read_html("https://www.usinflationcalculator.com/inflation/current-inflation-rates/#:~:text=The%20annual%20inflation%20rate%20for,12%20at%208%3A30%20a.m.")
df = df[0]
df.columns = df.iloc[0]
df = df[1:]

# %%
df.head()
# Out:
# 0  Year  Jan  Feb                Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 1  2023  6.4  6.0  Avail.  April  12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  2022  7.5  7.9                8.5  8.3  8.6  9.1  8.5  8.3  8.2  7.7  7.1
# 3  2021  1.4  1.7                2.6  4.2  5.0  5.4  5.4  5.3  5.4  6.2  6.8
# 4  2020  2.5  2.3                1.5  0.3  0.1  0.6  1.0  1.3  1.4  1.2  1.2
# 5  2019  1.6  1.5                1.9  2.0  1.8  1.6  1.8  1.7  1.7  1.8  2.1
#
# 0  Dec  Ave
# 1  NaN  NaN
# 2  6.5  8.0
# 3  7.0  4.7
# 4  1.4  1.2
# 5  2.3  1.8

# %%
df.to_csv('./data/Inflation_usa.csv',index=False)
